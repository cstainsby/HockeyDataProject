# %% [markdown]
# # Hockey Dataset Project
#
# ## Project Members
# - Cole Stainsby
# - Zach Ambroseo
# - Drew Bogdan
#
# ## Dataset Description
# [link](http://inalitic.com/datasets/nhl_leaguestandings_data.html) to initial dataset
# For the initial part of our project, we will be predicting whether a team will make it into the playoffs.
# ### Format and Contents of Data
# In Order data is
# - SEASON(int - year)
# - CONFERENCE(str - name)
# - DIVISION(str - name)
# - TEAM(str - name)
# - TM(str - name)
# - PLAYOFFS(char - Y/N)
# - GP(int)
# - W(int - wins)
# - L(int - losses)
# - T(int - ties)
# - OL(int - games lost in overtime)
# - PTS(int - number of points)
# - PTS%(double - num points/num shots)
# - GF(int - goals for)
# - GA(int - goals against)
# - SRS(double - Goals scored by player while team is on the powerplay. First recorded in the 1968 season.)
# - SOS(double - Goals scored by player while team is on the penalty kill (shorthanded). First recorded in the 1968 season.)
# - RPT%(double - Game winning goals scored by player in that season. First recorded in the 1968 season.)
# - ROW(double - Assists tallied by player while team is even strength. First recorded in the 1968 season.)
#
# ### Brief Description Of Attributes and Class Info
# The class attribute we will use from this data is the Playoffs attribute given that this is a binary Y/N classification.
# The rest of the attributes will be used in the training sets.
#
# ### Note:
# Given that this initial dataset is pretty straightforward, once we have finished creating a model for it we will attempt to create another model to predict who wins each of the tournament games using [this](https://moneypuck.com/data.htm) dataset. Additional documentation will be written as we advance and add more complexity
#
#
#
# ## Implementation and Technical Merit
# 1. Anticipated challenges in pre-processing and/or classification
#     Some issues with this dataset may be utilizing the data from this and the actual accuracy of who will win the games.
#     -The data from this year, while accurate, will not truly complete the dataset since they have not finished the season, they are about halfway through, and we will train our data on full seasons.
#     -The it will also be difficult to get an actual accurate prediction of who will win games. It will be easy to predict who will make it to the playoffs, however predicting who will win will be much more difficult due to roster changes and in games tempo can easily sway.
# 2. If the number of attributes is large, how will you explore feature selection techniques to pare down the attributes?
#     For this project we will attempt to sort out large numbers of attributes utilizing random forest and decision trees based upon the previous season of hockey.
#
# ## Potential Impact Of Results
# 1. Why are the results useful?
#  - The results of this project would be at its most basic form to predict what teams would currently make it into the stanley cup playoffs given their points and score. From there we want to take all the past champions and see who has won and their stats and figure out who would win the stanely cup given who made it in and their stats. Another plan for this project, but we are still mostly unsure how this will work is prediciting the outcomes of each series in the playoffs, figuring out who will win each series and by how much
# 2. Who are the stakeholders?
#  - The stake holders are people intrested in data, and the stanely cup. Another large stakeholder in this dataset would be gamblers and betting. if this dataset can become extremely accurate, betting on it could end up being very profitable, aside from an occasional upset, this would base it off of many stats, and build hopefully a fairly accurate prediction algorithm
